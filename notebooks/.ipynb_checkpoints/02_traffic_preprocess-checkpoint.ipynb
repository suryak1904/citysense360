# %%
from src.preprocess import TrafficPreprocessor

preprocessor = TrafficPreprocessor(window_size=24)

X, y, scaler = preprocessor.preprocess(
    "data/traffic/traffic.csv"
)

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.preprocess import TrafficPreprocessor
#       3 preprocessor = TrafficPreprocessor(window_size=24)
#       5 X, y, scaler = preprocessor.preprocess(
#       6     "data/traffic/traffic.csv"
#       7 )
#
# ModuleNotFoundError: No module named 'src'
